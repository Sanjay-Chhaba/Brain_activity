# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Bionic AI/')
from functions import *

# %% [markdown]
# ## Scenario 1: Base

# %%
with open('/content/drive/My Drive/Colab Notebooks/Bionic AI/Scenario 1 Models/Base/allPreds', 'rb') as f:
    allPreds = pickle.load(f)

with open('/content/drive/My Drive/Colab Notebooks/Bionic AI/Scenario 1 Models/Base/allTests', 'rb') as f:
    allTests = pickle.load(f)

AUC1B = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Bionic AI/Scenario 1 Models/Base/AUC')

# %%
AUC1B.mean = AUC1B.mean(axis=1)

# %%
AUC1B.mean.mean()
# Out:
# 0.7087071485153623

# %% [markdown]
# ## Scenario 1 CNN:

# %%
with open('/content/drive/My Drive/Colab Notebooks/Bionic AI/Scenario 1 Models/CNN/allPreds', 'rb') as f:
    allPreds = pickle.load(f)

with open('/content/drive/My Drive/Colab Notebooks/Bionic AI/Scenario 1 Models/CNN/allTests', 'rb') as f:
    allTests = pickle.load(f)

AUC1C = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Bionic AI/Scenario 1 Models/CNN/AUC')

# %%
AUC1C.mean= AUC1C.mean(axis=1)

# %%
AUC1C.mean.mean()
# Out:
# 0.8582299547149826

# %% [markdown]
# ## Scenario 2 Base:

# %%
with open('/content/drive/My Drive/Colab Notebooks/Bionic AI/Scenario 2 Models/Base/allPreds2', 'rb') as f:
    allPreds2 = pickle.load(f)

with open('/content/drive/My Drive/Colab Notebooks/Bionic AI/Scenario 2 Models/Base/allTests2', 'rb') as f:
    allTests2 = pickle.load(f)

AUC2B = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Bionic AI/Scenario 2 Models/Base/AUC2')

# %%
AUC2B.mean = AUC2B.mean(axis=1)

# %%
AUC2B.mean.mean()
# Out:
# 0.8266478607146253

# %% [markdown]
# ## Scenario 2 CNN

# %%
with open('/content/drive/My Drive/Colab Notebooks/Bionic AI/Scenario 2 Models/CNN/allPreds2', 'rb') as f:
    allPreds2 = pickle.load(f)

with open('/content/drive/My Drive/Colab Notebooks/Bionic AI/Scenario 2 Models/CNN/allTests2', 'rb') as f:
    allTests2 = pickle.load(f)

AUC2C = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Bionic AI/Scenario 2 Models/CNN/AUC2')

# %%
AUC2C.mean = AUC2C.mean(axis=1)

# %%
AUC2C.mean.mean()
# Out:
# 0.8762688434842536

# %% [markdown]
# ## Scenario 3 Base

# %%
with open('/content/drive/My Drive/Colab Notebooks/Bionic AI/Scenario 3 Models/Base/allPreds3', 'rb') as f:
    allPreds3 = pickle.load(f)

with open('/content/drive/My Drive/Colab Notebooks/Bionic AI/Scenario 3 Models/Base/allTests3', 'rb') as f:
    allTests3 = pickle.load(f)

AUC3B = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Bionic AI/Scenario 3 Models/Base/AUC3')

# %%
AUC3B['mean'] = AUC3B.mean(axis=1)

# %%
AUC3B['mean'].mean()
# Out:
# 0.8920886892837577

# %%
AUC3B
# Out:
#            0         1         2         3         4         5      mean
# 0   0.881099  0.971474  0.964731  0.926594  0.952582  0.907466  0.933991
# 1   0.821812  0.896689  0.892154  0.884108  0.954731  0.874611  0.887351
# 2   0.833022  0.861250  0.881240  0.855182  0.857138  0.888930  0.862794
# 3   0.851222  0.946682  0.950419  0.935456  0.813351  0.782962  0.880015
# 4   0.759226  0.964082  0.951525  0.877275  0.862800  0.859548  0.879076
# 5   0.905154  0.959263  0.953833  0.903711  0.832274  0.854958  0.901532
# 6   0.905277  0.962041  0.936206  0.943425  0.848858  0.801965  0.899629
# 7   0.711955  0.832268  0.850154  0.759358  0.899422  0.854716  0.817979
# 8   0.824162  0.930316  0.953152  0.969283  0.923354  0.915703  0.919329
# 9   0.920014  0.960565  0.955286  0.891294  0.950489  0.865527  0.923862
# 10  0.749452  0.902904  0.898081  0.901900  0.947182  0.890666  0.881698
# 11  0.897962  0.941978  0.941108  0.940993  0.969805  0.815009  0.917809

# %% [markdown]
# ## Scenario 3 CNN

# %%
with open('/content/drive/My Drive/Colab Notebooks/Bionic AI/Scenario 3 Models/CNN/allPreds3', 'rb') as f:
    allPreds3 = pickle.load(f)

with open('/content/drive/My Drive/Colab Notebooks/Bionic AI/Scenario 3 Models/CNN/allTests3', 'rb') as f:
    allTests3 = pickle.load(f)

AUC3C = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Bionic AI/Scenario 3 Models/CNN/AUC3')

# %%
AUC3C['mean'] = AUC3C.mean(axis=1)

# %%
AUC3C['mean'].mean()
# Out:
# 0.9288277810766111
